# %%
## 1. Import Libraries & Load Synthetic Titanic-like Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Capstone Proposal Structure (example)
proposal = {
    "title": "AI Maze Solver & Path Visualizer",
    "problem": "Given a grid-based maze with start and end points, find the optimal path and visualize the search process.",
    "goals": [
        "Implement BFS, DFS, and A* search",
        "Compare performance (nodes expanded, execution time)",
        "Visualize maze exploration and final path",
        "Optional: Deploy as API or dashboard"
    ],
    "dataset_or_env": "Synthetic grid mazes generated with Python",
    "tech_stack": [
        "Python", "NumPy", "Matplotlib/Pygame",
        "Flask/FastAPI (optional)", "Streamlit (optional UI)"
    ],
    "timeline_days": {
        "Day 29": "Maze representation + BFS/DFS + A*",
        "Day 30": "Visualization polish + Deployment + Final README"
    },
    "extras": [
        "Interactive visualization", "Heuristic tuning",
        "Model/API logging", "Large maze scaling tests"
    ]
}

# %%
df = pd.DataFrame({
    "Model Name": ["BFS", "DFS", "A*"],
    "Used For": ["Shortest path in unweighted maze", "Exploring all possible paths", "Optimal weighted pathfinding"],
    "Speed": ["Fast", "Fast", "Moderate"]
})

# %%
print("✅ Capstone Proposal Ready!")
print("\n📌 Proposal Dictionary:")
print(proposal)
# Out:
# ✅ Capstone Proposal Ready!
#
# 📌 Proposal Dictionary:
# {'title': 'AI Maze Solver & Path Visualizer', 'problem': 'Given a grid-based maze with start and end points, find the optimal path and visualize the search process.', 'goals': ['Implement BFS, DFS, and A* search', 'Compare performance (nodes expanded, execution time)', 'Visualize maze exploration and final path', 'Optional: Deploy as API or dashboard'], 'dataset_or_env': 'Synthetic grid mazes generated with Python', 'tech_stack': ['Python', 'NumPy', 'Matplotlib/Pygame', 'Flask/FastAPI (optional)', 'Streamlit (optional UI)'], 'timeline_days': {'Day 29': 'Maze representation + BFS/DFS + A*', 'Day 30': 'Visualization polish + Deployment + Final README'}, 'extras': ['Interactive visualization', 'Heuristic tuning', 'Model/API logging', 'Large maze scaling tests']}

# %%
print("\n📊 Algorithm Table:")
print(df)
# Out:
# 📊 Algorithm Table:
#   Model Name                          Used For     Speed
# 0        BFS  Shortest path in unweighted maze      Fast
# 1        DFS      Exploring all possible paths      Fast
# 2         A*      Optimal weighted pathfinding  Moderate
